# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the directories for the folders
train_dir = '/Users/reem/Downloads/chest_xray/train'
test_dir = '/Users/reem/Downloads/chest_xray/test'

# Prepare the data
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# Load the data
train_generator = train_datagen.flow_from_directory(
    train_dir, 
    target_size=(224, 224), 
    batch_size=32, 
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir, 
    target_size=(224, 224), 
    batch_size=32, 
    class_mode='binary'
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Build the model
model = Sequential([
    # First convolutional layer
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    # Second convolutional layer
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    # Third convolutional layer
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    # Flatten the output from convolutional layers
    Flatten(),
    
    # Fully connected layer
    Dense(128, activation='relu'),
    Dropout(0.5),  # Dropout for regularization
    
    # Output layer - binary classification
    Dense(1, activation='sigmoid')  # Sigmoid for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ...

# %%
# Train the model
history = model.fit(train_generator, epochs=10, validation_data=test_generator)

# Save the model after training
model.save('chest_xray_model.h5')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.7909 - loss: 0.4875
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 100s 606ms/step - accuracy: 0.7912 - loss: 0.4868 - val_accuracy: 0.8189 - val_loss: 0.3758
# Epoch 2/10
# ...

# %%
# Evaluate the model using test data
test_loss, test_acc = model.evaluate(test_generator)

# Print the test accuracy
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.8338 - loss: 0.4093
# Test Accuracy: 83.17%

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# List the files in the 'PNEUMONIA' and 'NORMAL' folders within 'train', 'test', and 'val'
train_pneumonia_files = os.listdir(os.path.join(train_dir, 'PNEUMONIA'))
train_normal_files = os.listdir(os.path.join(train_dir, 'NORMAL'))

test_pneumonia_files = os.listdir(os.path.join(test_dir, 'PNEUMONIA'))
test_normal_files = os.listdir(os.path.join(test_dir, 'NORMAL'))

val_pneumonia_files = os.listdir(os.path.join(val_dir, 'PNEUMONIA'))
val_normal_files = os.listdir(os.path.join(val_dir, 'NORMAL'))

print("Train Pneumonia Files:", train_pneumonia_files[:5])  # Show first 5 files for example
print("Train Normal Files:", train_normal_files[:5])
print("Test Pneumonia Files:", test_pneumonia_files[:5])
print("Test Normal Files:", test_normal_files[:5])
print("Validation Pneumonia Files:", val_pneumonia_files[:5])
print("Validation Normal Files:", val_normal_files[:5])
# Out:
# Train Pneumonia Files: ['person63_bacteria_306.jpeg', 'person1438_bacteria_3721.jpeg', 'person755_bacteria_2659.jpeg', 'person478_virus_975.jpeg', 'person661_bacteria_2553.jpeg']
# Train Normal Files: ['NORMAL2-IM-0927-0001.jpeg', 'NORMAL2-IM-1056-0001.jpeg', 'IM-0427-0001.jpeg', 'NORMAL2-IM-1260-0001.jpeg', 'IM-0656-0001-0001.jpeg']
# Test Pneumonia Files: ['person147_bacteria_706.jpeg', 'person100_bacteria_482.jpeg', 'person78_bacteria_382.jpeg', 'person124_bacteria_589.jpeg', 'person1647_virus_2848.jpeg']
# Test Normal Files: ['IM-0031-0001.jpeg', 'IM-0025-0001.jpeg', 'NORMAL2-IM-0272-0001.jpeg', 'NORMAL2-IM-0102-0001.jpeg', 'NORMAL2-IM-0229-0001.jpeg']
# Validation Pneumonia Files: ['person1950_bacteria_4881.jpeg', 'person1951_bacteria_4882.jpeg', 'person1952_bacteria_4883.jpeg', 'person1946_bacteria_4874.jpeg', 'person1947_bacteria_4876.jpeg']
# ...

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import tensorflow as tf

# Load the pre-trained model
model = tf.keras.models.load_model('/Users/reem/Downloads/chest_xray/chest_xray_model.h5')

# Define a function to predict a single image
def predict_image(img_path):
    # Load and process the image
    img = image.load_img(img_path, target_size=(224, 224))  # Adjust target_size if necessary
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    
    # Predict using the model
    prediction = model.predict(img_array)
    
    # Return the result (0 or 1 for classification)
    return "Normal" if prediction[0][0] < 0.5 else "Pneumonia"

# Test the prediction with an image from the validation folder
img_path = '/Users/reem/Downloads/chest_xray/val/NORMAL/NORMAL2-IM-0927-0001.jpeg'  # Replace with your image path
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import image

# Load the pre-trained model
model = tf.keras.models.load_model('/Users/reem/Downloads/chest_xray/chest_xray_model.h5')

# Compile the model (if you want to use metrics or train the model further)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Define a function to predict a single image
def predict_image(img_path):
    # Load and process the image
    img = image.load_img(img_path, target_size=(224, 224))  # Adjust target_size if necessary
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    
    # Predict using the model
    prediction = model.predict(img_array)
    
    # Return the result (0 or 1 for classification)
    return "Normal" if prediction[0][0] < 0.5 else "Pneumonia"

# Test the prediction with an image from the validation folder
img_path = '/Users/reem/Downloads/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg'
result = predict_image(img_path)

# Print the prediction result
print(f'Prediction: {result}')

# Display the image
img = image.load_img(img_path)
img_array = image.img_to_array(img)
plt.imshow(img_array.astype('uint8'))
plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Prediction: Pneumonia
